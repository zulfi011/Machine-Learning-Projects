# %% [markdown]
# # there are three types of recomender systems
#
# *   content based
# *   collaborative based
# *   Hybrid
# ---
# Our model will mostly be content based

# %%
import numpy as np
import pandas as pd
import difflib
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
df = pd.read_csv('/content/movies.csv')
df.sample(5)
# Out:
#       index    budget                genres  \
# 3061   3061  10000000                 Drama
# 436     436  80000000                Comedy
# 2243   2243  20000000           Drama Music
# 1130   1130  42000000                Comedy
# 2677   2677         0  Comedy Drama Romance
#
#                                           homepage      id  \
# 3061                                           NaN     404
# 436   http://www.sonypictures.com/movies/grownups2  109418
# 2243              http://www.imnotthere-movie.com/    3902
# 1130                                           NaN   18480
# 2677      http://www.gooddeedsmovie.com/index.html   62008
#
#                                                keywords original_language  \
# 3061  brother brother relationship mississippi wisco...                en
# 436                                                 NaN                en
# 2243  rock and roll music style success john f. kenn...                en
# 1130               gay fame mockumentary hollywood lgbt                en
# 2677  african american single mother fianc\u00e9 fia...                en
#
#           original_title                                           overview  \
# 3061  The Straight Story  "The Straight Story" chronicles a trip made by...
# 436          Grown Ups 2  The all-star comedy cast from Grown Ups return...
# 2243      I'm Not There.  Six actors portray six personas of music legen...
# 1130               Brüno  Flamboyantly gay Austrian television reporter ...
# 2677          Good Deeds  Businessman Wesley Deeds is jolted out of his ...
#
#       popularity  ... runtime  \
# 3061   15.280261  ...   112.0
# 436    45.589568  ...   100.0
# 2243   13.032308  ...   135.0
# 1130   16.122168  ...    83.0
# 2677    4.448494  ...   111.0
#
#                                        spoken_languages    status  \
# 3061           [{"iso_639_1": "en", "name": "English"}]  Released
# 436            [{"iso_639_1": "en", "name": "English"}]  Released
# 2243           [{"iso_639_1": "en", "name": "English"}]  Released
# 1130  [{"iso_639_1": "cs", "name": "\u010cesk\u00fd"...  Released
# 2677           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                                 tagline               title  \
# 3061                                                NaN  The Straight Story
# 436   Just because they're a little older doesn't me...         Grown Ups 2
# 2243              All I Can Do Is Be Me Whoever That Is      I'm Not There.
# 1130                                  Borat was so 2006               Brüno
# 2677  Wesley Deeds is About to Discover the Person H...          Good Deeds
#
#      vote_average vote_count  \
# 3061          7.7        306
# 436           5.8       1155
# 2243          6.6        195
# 1130          5.4        518
# 2677          6.2         45
#
#                                                    cast  \
# 3061  Richard Farnsworth Sissy Spacek Jane Galloway ...
# 436   Adam Sandler Kevin James Chris Rock David Spad...
# 2243  Cate Blanchett Heath Ledger Julianne Moore Ben...
# 1130  Sacha Baron Cohen Richard Bey Ron Paul Gustaf ...
# 2677  Tyler Perry Phylicia Rash\u0101d Thandie Newto...
#
#                                                    crew       director
# 3061  [{'name': 'David Lynch', 'gender': 2, 'departm...    David Lynch
# 436   [{'name': 'Rupert Gregson-Williams', 'gender':...   Dennis Dugan
# 2243  [{'name': 'Jay Rabinowitz', 'gender': 2, 'depa...    Todd Haynes
# 1130  [{'name': 'Sacha Baron Cohen', 'gender': 2, 'd...  Larry Charles
# 2677  [{'name': 'Kim Coleman', 'gender': 1, 'departm...    Tyler Perry
#
# [5 rows x 24 columns]

# %%
df.shape
# Out:
# (4803, 24)

# %%
df.columns
# Out:
# Index(['index', 'budget', 'genres', 'homepage', 'id', 'keywords',
#        'original_language', 'original_title', 'overview', 'popularity',
#        'production_companies', 'production_countries', 'release_date',
#        'revenue', 'runtime', 'spoken_languages', 'status', 'tagline', 'title',
#        'vote_average', 'vote_count', 'cast', 'crew', 'director'],
#       dtype='object')

# %%
df = df[['genres','id','keywords','overview','title','vote_average','vote_count','cast','director']]

# %%
df.sample(2)
# Out:
#                      genres     id  \
# 3591  Action Crime Thriller  21610
# 2281                 Comedy  11247
#
#                                               keywords  \
# 3591                                               NaN
# 2281  jealousy cinderella work step mother high school
#
#                                                overview               title  \
# 3591  An international terrorist has New York in a g...          Nighthawks
# 2281  Sam Montgomery is a tomboyish, unpopular girl ...  A Cinderella Story
#
#       vote_average  vote_count  \
# 3591           6.4          86
# 2281           6.1         713
#
#                                                    cast       director
# 3591  Sylvester Stallone Rutger Hauer Billy Dee Will...  Bruce Malmuth
# 2281  Hilary Duff Jennifer Coolidge Chad Michael Mur...    Mark Rosman

# %%
df.shape
# Out:
# (4803, 9)

# %%
df.isna().sum()
# Out:
# genres           28
# id                0
# keywords        412
# overview          3
# title             0
# vote_average      0
# vote_count        0
# cast             43
# director         30
# dtype: int64

# %% [markdown]
# # joining our main content

# %%
combined_lst = ['genres','keywords','overview','cast','director']
for i in combined_lst:
    df[i] = df[i].fillna('')
def join_content(row):
    return f"{row['genres']} {row['keywords']} {row['overview']} {row['cast']} {row['director']}"
df['combined_content'] = df.apply(join_content, axis=1)

# %%
df.isna().sum()
# Out:
# genres              0
# id                  0
# keywords            0
# overview            0
# title               0
# vote_average        0
# vote_count          0
# cast                0
# director            0
# combined_content    0
# dtype: int64

# %%
df['combined_content']
# Out:
# 0       Action Adventure Fantasy Science Fiction cultu...
# 1       Adventure Fantasy Action ocean drug abuse exot...
# 2       Action Adventure Crime spy based on novel secr...
# 3       Action Crime Drama Thriller dc comics crime fi...
# 4       Action Adventure Science Fiction based on nove...
#                               ...
# 4798    Action Crime Thriller united states\u2013mexic...
# 4799    Comedy Romance  A newlywed couple's honeymoon ...
# 4800    Comedy Drama Romance TV Movie date love at fir...
# 4801      When ambitious New York attorney Sam is sent...
# 4802    Documentary obsession camcorder crush dream gi...
# Name: combined_content, Length: 4803, dtype: object

# %% [markdown]
# # Handling Scoring

# %%
C = df['vote_average'].mean()
m = df['vote_count'].quantile(0.70)  # Only consider movies with enough votes

def weighted_rating(x, m=m, C=C):
    v = x['vote_count']
    R = x['vote_average']
    return (v/(v + m))*R + (m/(v + m))*C # IMDb Weighted Rating formula

df['score'] = df.apply(weighted_rating, axis=1)

# %%
df['score']
# Out:
# 0       7.148013
# 1       6.807627
# 2       6.276075
# 3       7.509565
# 4       6.098319
#           ...
# 4798    6.239746
# 4799    6.090532
# 4800    6.101451
# 4801    6.087503
# 4802    6.097742
# Name: score, Length: 4803, dtype: float64

# %%
df.reset_index(drop=True,inplace=True)

# %%
movie_data = df[['id','title','score','combined_content']]

# %%
movie_data.shape
# Out:
# (4803, 4)

# %%
movie_data
# Out:
#           id                                     title     score  \
# 0      19995                                    Avatar  7.148013
# 1        285  Pirates of the Caribbean: At World's End  6.807627
# 2     206647                                   Spectre  6.276075
# 3      49026                     The Dark Knight Rises  7.509565
# 4      49529                               John Carter  6.098319
# ...      ...                                       ...       ...
# 4798    9367                               El Mariachi  6.239746
# 4799   72766                                 Newlyweds  6.090532
# 4800  231617                 Signed, Sealed, Delivered  6.101451
# 4801  126186                          Shanghai Calling  6.087503
# 4802   25975                         My Date with Drew  6.097742
#
#                                        combined_content
# 0     Action Adventure Fantasy Science Fiction cultu...
# 1     Adventure Fantasy Action ocean drug abuse exot...
# 2     Action Adventure Crime spy based on novel secr...
# 3     Action Crime Drama Thriller dc comics crime fi...
# 4     Action Adventure Science Fiction based on nove...
# ...                                                 ...
# 4798  Action Crime Thriller united states\u2013mexic...
# 4799  Comedy Romance  A newlywed couple's honeymoon ...
# 4800  Comedy Drama Romance TV Movie date love at fir...
# 4801    When ambitious New York attorney Sam is sent...
# 4802  Documentary obsession camcorder crush dream gi...
#
# [4803 rows x 4 columns]

# %%
movie_data.to_csv('processed.csv',index=False)
